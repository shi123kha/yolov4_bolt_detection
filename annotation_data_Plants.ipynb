# %% [markdown]
# # Augmenting a dataset for object detection in YOLO
#
# In this notebook, we illustrate how CLODSA can be employed to augment a dataset of images devoted to object detection using the [YOLO format](https://pjreddie.com/darknet/yolo/). In particular, we use a subset of the [Pascal VOC dataset](http://host.robots.ox.ac.uk/pascal/VOC/). We will use 20 images from that dataset. Such a subset can be downloaded by executing the following command.

# %% [markdown]
# We can check the amount of images in each one of the folders.

# %%
print("Number of images in the folder")
# !ls -1 PascalVOCYOLO/*.jpg | wc -l
# Out:
# Number of images in the folder
# ls: cannot access 'PascalVOCYOLO/*.jpg': No such file or directory
# 0

# %% [markdown]
# ## Augmentation techniques
#
# In this notebook, we will use the following augmentation techniques:
# - Vertical, horizontal, and vertical-horizontal flips.
# - 180º Rotation.
# - Average blurring.
# - Raise the hue value.

# %% [markdown]
# ## Installing the necessary libraries
#
# In case that CLODSA is not installed in your system, the first task consists in installing it using ``pip``.

# %%
# !pip install clodsa
# Out:
# Requirement already satisfied: clodsa in /usr/local/lib/python3.7/dist-packages (1.2.47)
# Requirement already satisfied: progressbar2 in /usr/local/lib/python3.7/dist-packages (from clodsa) (3.38.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from clodsa) (1.4.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from clodsa) (1.0.2)
# Requirement already satisfied: mahotas in /usr/local/lib/python3.7/dist-packages (from clodsa) (1.4.12)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from clodsa) (1.1.0)
# Requirement already satisfied: imutils in /usr/local/lib/python3.7/dist-packages (from clodsa) (0.5.4)
# Requirement already satisfied: commentjson in /usr/local/lib/python3.7/dist-packages (from clodsa) (0.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from clodsa) (1.19.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from clodsa) (3.1.0)
# Requirement already satisfied: Keras in /usr/local/lib/python3.7/dist-packages (from clodsa) (2.7.0)
# Requirement already satisfied: lark-parser<0.8.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from commentjson->clodsa) (0.7.8)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->clodsa) (1.5.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from progressbar2->clodsa) (1.15.0)
# Requirement already satisfied: python-utils>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from progressbar2->clodsa) (3.0.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->clodsa) (3.0.0)

# %% [markdown]
# ## Loading the necessary libraries
#
# The first step in the pipeline consists in loading the necessary libraries to apply the data augmentation techniques in CLODSA. We also load some libraries to show the results.

# %%
from matplotlib import pyplot as plt
from clodsa.augmentors.augmentorFactory import createAugmentor
from clodsa.transformers.transformerFactory import transformerGenerator
from clodsa.techniques.techniqueFactory import createTechnique
import xml.etree.ElementTree as ET
import cv2
# %matplotlib inline

# %% [markdown]
# ## Creating the augmentor object
#
# As explained in the documentation of CLODSA, we need to specify some parameters for the augmentation process, and use them to create an augmentor object.
#
# _The kind of problem_. In this case, we are working in a detection problem

# %%
PROBLEM = "detection"

# %% [markdown]
# _The annotation mode_. We use the YOLO format.

# %%
ANNOTATION_MODE = "yolo"

# %% [markdown]
# _The input path_. The input path containing the images.

# %%
#INPUT_PATH = "PascalVOCYOLO/"
INPUT_PATH='/content/drive/MyDrive/sbi_yolov4/vacnt/'

# %% [markdown]
# _The generation mode_. In this case, linear, that is, all the augmentation techniques are applied to all the images of the original dataset.

# %%
GENERATION_MODE = "linear"

# %% [markdown]
# _The output mode_. The generated images will be stored in a new folder called augmented_images.

# %%
OUTPUT_MODE = "yolo"
OUTPUT_PATH= "augmented_images_yolo_empty_1"

# %% [markdown]
# Using the above information, we can create our augmentor object.

# %%
augmentor = createAugmentor(PROBLEM,ANNOTATION_MODE,OUTPUT_MODE,GENERATION_MODE,INPUT_PATH,{"outputPath":OUTPUT_PATH})

# %% [markdown]
# ## Adding the augmentation techniques
#
# Now, we define the techniques that will be applied in our augmentation process and add them to our augmentor object. To illustrate the transformations, we will use the following image of the dataset.

# %%
img = cv2.imread("/content/drive/MyDrive/sbi_yolov4/vacnt/1.jpeg")
# changing to the BGR format of OpenCV to RGB format for matplotlib
plt.imshow(img[:,:,::-1])

# %% [markdown]
# Just for showing the results of applying data augmentation in an object detection problem, we define a function to read the annotations and another one to show them. This funcionality is not necessary when using CLODSA since it is already implemented in there.

# %%
def boxesFromYOLO(imagePath,labelPath):
    image = cv2.imread(imagePath)
    (hI, wI) = image.shape[:2]
    lines = [line.rstrip('\n') for line in open(labelPath)]
    #if(len(objects)<1):
    #    raise Exception("The xml should contain at least one object")
    boxes = []
    if lines != ['']:
        for line in lines:
            components = line.split(" ")
            category = components[0]
            x  = int(float(components[1])*wI - float(components[3])*wI/2)
            y = int(float(components[2])*hI - float(components[4])*hI/2)
            h = int(float(components[4])*hI)
            w = int(float(components[3])*wI)
            boxes.append((category, (x, y, w, h)))
    return (image,boxes)

# %%
categoriesColors = {11: (255,0,0),14:(0,0,255)}

def showBoxes(image,boxes):
    cloneImg = image.copy()
    for box in boxes:
        if(len(box)==2):
            (category, (x, y, w, h))=box
        else:
            (category, (x, y, w, h),_)=box
        if int(category) in categoriesColors.keys():
            cv2.rectangle(cloneImg,(x,y),(x+w,y+h),categoriesColors[int(category)],5)
        else:
            cv2.rectangle(cloneImg,(x,y),(x+w,y+h),(0,255,0),5)
    plt.imshow(cloneImg[:,:,::-1])

# %% [markdown]
# Now, we show the annotation of the image.

# %%
img,boxes = boxesFromYOLO("/content/drive/MyDrive/sbi_yolov4/vacnt/1.jpeg","/content/drive/MyDrive/sbi_yolov4/vacnt/1.txt")
showBoxes(img,boxes)

# %% [markdown]
# First of all, we must define a transformer generator.

# %%
transformer = transformerGenerator(PROBLEM)

# %% [markdown]
# #### Vertical flip

# %%
vFlip = createTechnique("flip",{"flip":0})
augmentor.addTransformer(transformer(vFlip))

# %% [markdown]
# Showing the result of applying the transformation.

# %%
plt.figure()
plt.title("Original")
showBoxes(img,boxes)
vFlipGenerator = transformer(vFlip)
vFlipImg,vFlipBoxes = vFlipGenerator.transform(img,boxes)
plt.figure()
plt.title("Transformed")
showBoxes(vFlipImg,vFlipBoxes)

# %% [markdown]
# #### Horizontal flip

# %%
hFlip = createTechnique("flip",{"flip":1})
augmentor.addTransformer(transformer(hFlip))

# %% [markdown]
# Showing the result of applying the transformation.

# %%
plt.figure()
plt.title("Original")
showBoxes(img,boxes)
hFlipGenerator = transformer(hFlip)
hFlipImg,hFlipBoxes = hFlipGenerator.transform(img,boxes)
plt.figure()
plt.title("Transformed")
showBoxes(hFlipImg,hFlipBoxes)

# %% [markdown]
# #### Horizontal and vertical flip

# %%
hvFlip = createTechnique("flip",{"flip":-1})
augmentor.addTransformer(transformer(hvFlip))

# %% [markdown]
# Showing the result of applying the transformation.

# %%
plt.figure()
plt.title("Original")
showBoxes(img,boxes)
hvFlipGenerator = transformer(hvFlip)
hvFlipImg,hvFlipBoxes = hvFlipGenerator.transform(img,boxes)
plt.figure()
plt.title("Transformed")
showBoxes(hvFlipImg,hvFlipBoxes)

# %% [markdown]
# #### Rotation:

# %%
rotate = createTechnique("rotate", {"angle" : 90})
augmentor.addTransformer(transformer(rotate))

# %% [markdown]
# Showing the result of applying the transformation.

# %%
plt.figure()
plt.title("Original")
showBoxes(img,boxes)
rotateGenerator = transformer(rotate)
rotateImg,rotateBoxes = rotateGenerator.transform(img,boxes)
plt.figure()
plt.title("Transformed")
showBoxes(rotateImg,rotateBoxes)

# %% [markdown]
# #### Average blurring

# %%
avgBlur =  createTechnique("average_blurring", {"kernel" : 5})
augmentor.addTransformer(transformer(avgBlur))

# %% [markdown]
# Showing the result of applying the transformation.

# %%
plt.figure()
plt.title("Original")
showBoxes(img,boxes)
avgBlurGenerator = transformer(avgBlur)
avgBlurImg,avgBlurBoxes = avgBlurGenerator.transform(img,boxes)
plt.figure()
plt.title("Transformed")
showBoxes(avgBlurImg,avgBlurBoxes)

# %% [markdown]
# #### Raise Hue

# %%
hue = createTechnique("raise_hue", {"power" : 0.9})
augmentor.addTransformer(transformer(hue))

# %% [markdown]
# Showing the result of applying the transformation.

# %%
plt.figure()
plt.title("Original")
showBoxes(img,boxes)
hueGenerator = transformer(hue)
hueImg,hueBoxes = hueGenerator.transform(img,boxes)
plt.figure()
plt.title("Transformed")
showBoxes(hueImg,hueBoxes)

# %% [markdown]
# #### None
# (to keep also the original image)

# %%
none = createTechnique("none",{})
augmentor.addTransformer(transformer(none))

# %% [markdown]
# ## Applying the augmentation process
#
# Finally, we apply the augmentation process (this might take some time depending on the number of images of the original dataset and the number of transformations that will be applied).

# %%
augmentor.applyAugmentation()
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-109-1d9c8eaf67b6> in <module>()
# ----> 1 augmentor.applyAugmentation()
#
# /usr/local/lib/python3.7/dist-packages/clodsa/augmentors/yoloLinearDetectionAugmentor.py in applyAugmentation(self)
#      88         self.readImagesAndAnnotations()
#      89         if not(os._exists(self.outputPath)):
# ---> 90             os.makedirs(self.outputPath)
#      91         Parallel(n_jobs=-1)(delayed(readAndGenerateImage)(self.outputPath,self.transformers,x) for x in enumerate(self.imagePaths))
#      92
#
# /usr/lib/python3.7/os.py in makedirs(name, mode, exist_ok)
#     221             return
#     222     try:
# --> 223         mkdir(name, mode)
#     224     except OSError:
#     225         # Cannot rely on checking for EEXIST, since the operating system
#
# FileExistsError: [Errno 17] File exists: 'augmented_images_yolo_empty_1'

# %% [markdown]
# Finally, we can check the amount of images in the output folder.

# %%
print("Number of images in the folder")
# !ls -1 /content/drive/MyDrive/sbi_yolov4/darknet/data_bolt/*.jpg | wc -l
print("Number of annotations in the folder")
# !ls -1 /content/drive/MyDrive/sbi_yolov4/darknet/data_bolt/*.txt | wc -l

# %%
# !zip -r /content/augmented_images_yolo_empty_1.zip /content/augmented_images_yolo_empty_1
from google.colab import files
files.download('/content/augmented_images_yolo_empty_1.zip')
# Out:
#   adding: content/augmented_images_yolo_empty_1/ (stored 0%)
#   adding: content/augmented_images_yolo_empty_1/1_0_2.txt (deflated 58%)
#   adding: content/augmented_images_yolo_empty_1/3_0_4.jpeg (deflated 1%)
#   adding: content/augmented_images_yolo_empty_1/2_5_3.jpeg (deflated 3%)
#   adding: content/augmented_images_yolo_empty_1/0_2_1.jpeg (deflated 0%)
#   adding: content/augmented_images_yolo_empty_1/0_2_1.txt (deflated 44%)
#   adding: content/augmented_images_yolo_empty_1/4_3_5.jpeg (deflated 1%)
#   adding: content/augmented_images_yolo_empty_1/0_4_1.jpeg (deflated 0%)
#   adding: content/augmented_images_yolo_empty_1/5_6_6.jpeg (deflated 7%)
#   adding: content/augmented_images_yolo_empty_1/2_4_3.txt (deflated 53%)
#   adding: content/augmented_images_yolo_empty_1/2_0_3.txt (deflated 54%)
#   adding: content/augmented_images_yolo_empty_1/2_6_3.jpeg (deflated 5%)
#   adding: content/augmented_images_yolo_empty_1/4_6_5.jpeg (deflated 4%)
#   adding: content/augmented_images_yolo_empty_1/4_0_5.jpeg (deflated 4%)
#   adding: content/augmented_images_yolo_empty_1/3_4_4.txt (deflated 64%)
#   adding: content/augmented_images_yolo_empty_1/3_1_4.txt (deflated 67%)
#   adding: content/augmented_images_yolo_empty_1/3_4_4.jpeg (deflated 1%)
#   adding: content/augmented_images_yolo_empty_1/1_6_2.txt (deflated 60%)
#   adding: content/augmented_images_yolo_empty_1/2_0_3.jpeg (deflated 1%)
#   adding: content/augmented_images_yolo_empty_1/0_1_1.jpeg (deflated 0%)
#   adding: content/augmented_images_yolo_empty_1/0_6_1.jpeg (deflated 0%)
#   adding: content/augmented_images_yolo_empty_1/3_0_4.txt (deflated 65%)
#   adding: content/augmented_images_yolo_empty_1/4_2_5.jpeg (deflated 1%)
#   adding: content/augmented_images_yolo_empty_1/0_3_1.jpeg (deflated 0%)
#   adding: content/augmented_images_yolo_empty_1/4_1_5.txt (deflated 60%)
#   adding: content/augmented_images_yolo_empty_1/3_3_4.txt (deflated 65%)
#   adding: content/augmented_images_yolo_empty_1/1_2_2.jpeg (deflated 1%)
#   adding: content/augmented_images_yolo_empty_1/3_2_4.jpeg (deflated 1%)
#   adding: content/augmented_images_yolo_empty_1/1_4_2.txt (deflated 60%)
#   adding: content/augmented_images_yolo_empty_1/1_1_2.txt (deflated 57%)
#   adding: content/augmented_images_yolo_empty_1/1_0_2.jpeg (deflated 1%)
#   adding: content/augmented_images_yolo_empty_1/2_1_3.jpeg (deflated 1%)
#   adding: content/augmented_images_yolo_empty_1/5_1_6.txt (deflated 57%)
#   adding: content/augmented_images_yolo_empty_1/5_1_6.jpeg (deflated 1%)
#   adding: content/augmented_images_yolo_empty_1/1_2_2.txt (deflated 59%)
#   adding: content/augmented_images_yolo_empty_1/0_3_1.txt (deflated 44%)
#   adding: content/augmented_images_yolo_empty_1/4_5_5.jpeg (deflated 2%)
#   adding: content/augmented_images_yolo_empty_1/5_3_6.txt (deflated 58%)
#   adding: content/augmented_images_yolo_empty_1/4_1_5.jpeg (deflated 1%)
#   adding: content/augmented_images_yolo_empty_1/1_3_2.txt (deflated 59%)
#   adding: content/augmented_images_yolo_empty_1/3_5_4.txt (deflated 64%)
#   adding: content/augmented_images_yolo_empty_1/2_3_3.jpeg (deflated 1%)
#   adding: content/augmented_images_yolo_empty_1/4_4_5.txt (deflated 63%)
#   adding: content/augmented_images_yolo_empty_1/0_4_1.txt (deflated 45%)
#   adding: content/augmented_images_yolo_empty_1/4_4_5.jpeg (deflated 1%)
#   adding: content/augmented_images_yolo_empty_1/5_0_6.txt (deflated 58%)
#   adding: content/augmented_images_yolo_empty_1/1_6_2.jpeg (deflated 4%)
#   adding: content/augmented_images_yolo_empty_1/3_6_4.txt (deflated 64%)
#   adding: content/augmented_images_yolo_empty_1/3_5_4.jpeg (deflated 5%)
#   adding: content/augmented_images_yolo_empty_1/2_6_3.txt (deflated 53%)
#   adding: content/augmented_images_yolo_empty_1/4_3_5.txt (deflated 63%)
#   adding: content/augmented_images_yolo_empty_1/5_5_6.txt (deflated 57%)
#   adding: content/augmented_images_yolo_empty_1/0_5_1.txt (deflated 45%)
#   adding: content/augmented_images_yolo_empty_1/1_5_2.jpeg (deflated 2%)
#   adding: content/augmented_images_yolo_empty_1/5_2_6.txt (deflated 57%)
#   adding: content/augmented_images_yolo_empty_1/5_4_6.jpeg (deflated 1%)
#   adding: content/augmented_images_yolo_empty_1/1_1_2.jpeg (deflated 1%)
#   adding: content/augmented_images_yolo_empty_1/4_6_5.txt (deflated 63%)
#   adding: content/augmented_images_yolo_empty_1/2_3_3.txt (deflated 54%)
#   adding: content/augmented_images_yolo_empty_1/4_2_5.txt (deflated 61%)
#   adding: content/augmented_images_yolo_empty_1/1_3_2.jpeg (deflated 1%)
#   adding: content/augmented_images_yolo_empty_1/5_0_6.jpeg (deflated 1%)
#   adding: content/augmented_images_yolo_empty_1/0_6_1.txt (deflated 45%)
#   adding: content/augmented_images_yolo_empty_1/4_0_5.txt (deflated 62%)
#   adding: content/augmented_images_yolo_empty_1/0_0_1.txt (deflated 44%)
#   adding: content/augmented_images_yolo_empty_1/2_5_3.txt (deflated 53%)
#   adding: content/augmented_images_yolo_empty_1/3_6_4.jpeg (deflated 7%)
#   adding: content/augmented_images_yolo_empty_1/5_6_6.txt (deflated 57%)
#   adding: content/augmented_images_yolo_empty_1/1_5_2.txt (deflated 60%)
#   adding: content/augmented_images_yolo_empty_1/1_4_2.jpeg (deflated 1%)
#   adding: content/augmented_images_yolo_empty_1/5_2_6.jpeg (deflated 1%)
#   adding: content/augmented_images_yolo_empty_1/5_3_6.jpeg (deflated 1%)
#   adding: content/augmented_images_yolo_empty_1/3_3_4.jpeg (deflated 1%)
#   adding: content/augmented_images_yolo_empty_1/0_0_1.jpeg (deflated 0%)
#   adding: content/augmented_images_yolo_empty_1/2_1_3.txt (deflated 52%)
#   adding: content/augmented_images_yolo_empty_1/3_1_4.jpeg (deflated 1%)
#   adding: content/augmented_images_yolo_empty_1/3_2_4.txt (deflated 65%)
#   adding: content/augmented_images_yolo_empty_1/0_5_1.jpeg (deflated 0%)
#   adding: content/augmented_images_yolo_empty_1/2_2_3.txt (deflated 55%)
#   adding: content/augmented_images_yolo_empty_1/5_5_6.jpeg (deflated 5%)
#   adding: content/augmented_images_yolo_empty_1/2_4_3.jpeg (deflated 1%)
#   adding: content/augmented_images_yolo_empty_1/5_4_6.txt (deflated 57%)
#   adding: content/augmented_images_yolo_empty_1/0_1_1.txt (deflated 44%)
#   adding: content/augmented_images_yolo_empty_1/2_2_3.jpeg (deflated 1%)
#   adding: content/augmented_images_yolo_empty_1/4_5_5.txt (deflated 63%)
